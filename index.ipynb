# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge on Join statements.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
cur.execute('''SELECT * 
                 FROM employees e 
                 JOIN offices o 
                   ON e.officeCode = o.officeCode
                WHERE o.city = "Boston" ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   employeeNumber   lastName firstName extension  \
# 0           1188   Firrelli     Julie     x2173
# 1           1216  Patterson     Steve     x4334
#
#                              email officeCode reportsTo   jobTitle officeCode  \
# 0   jfirrelli@classicmodelcars.com          2      1143  Sales Rep          2
# 1  spatterson@classicmodelcars.com          2      1143  Sales Rep          2
#
#      city            phone      addressLine1 addressLine2 state country  \
# 0  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA     USA
# 1  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA     USA
#
#   postalCode territory
# 0      02107        NA
# 1      02107        NA

# %% [markdown]
# ## Do any offices have no employees?

# %%
cur.execute('''SELECT * 
                 FROM offices o
                 JOIN employees e
                   ON e.officeCode = o.officeCode
                WHERE o.officeCode NOT in e.officeCode;
                 ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-15-4b5b86d7a6f7> in <module>()
#       4                    ON e.officeCode = o.officeCode
#       5                 WHERE o.officeCode NOT in e.officeCode;
# ----> 6                  ''')
#       7 df = pd.DataFrame(cur.fetchall())
#       8 df.columns = [i[0] for i in cur.description]
#
# OperationalError: no such table: e.officeCode

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
cur.execute('''SELECT e.officeCode as office, o.city, SUM(p.amount) as total_sales 
                 FROM employees e
                 JOIN customers c
                   ON e.employeeNumber = c.salesRepEmployeeNumber
                 JOIN  p
                   ON p.customerNumber = c.customerNumber
                 JOIN offices o 
                   ON e.officeCode = o.officeCode
             GROUP BY 1, 2
             ORDER BY  3 DESC''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head(20)
# Out:
#   office           city  total_sales
# 0      4          Paris   2819168.90
# 1      1  San Francisco   1337439.58
# 2      7         London   1324325.90
# 3      3            NYC   1072619.47
# 4      6         Sydney   1007292.98
# 5      2         Boston    835882.33
# 6      5          Tokyo    457110.07

# %%
cur.execute('''SELECT pr.productName, pr.MSRP, od.orderNumber, o.status
                 FROM products pr
                 JOIN orderDetails od
                   ON pr.productCode = od.productCode
                 JOIN orders o
                   ON od.orderNumber = o.orderNumber
                WHERE o.status NOT LIKE 'shipped'
             ORDER BY 2 DESC
                   
                   ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head(20)
# Out:
#                               productName   MSRP orderNumber      status
# 0                        1997 BMW F650 ST  99.89       10179   Cancelled
# 1                        1997 BMW F650 ST  99.89       10401     On Hold
# 2          America West Airlines B757-200  99.72       10262   Cancelled
# 3          America West Airlines B757-200  99.72       10386    Resolved
# 4          America West Airlines B757-200  99.72       10401     On Hold
# 5                          The Queen Mary  99.31       10167   Cancelled
# 6                          The Queen Mary  99.31       10248   Cancelled
# 7                          The Queen Mary  99.31       10327    Resolved
# 8                          The Queen Mary  99.31       10386    Resolved
# 9                          The Queen Mary  99.31       10414     On Hold
# 10               1917 Maxwell Touring Car  99.21       10423  In Process
# 11                  1936 Chrysler Airflow  97.39       10423  In Process
# 12            1980’s GM Manhattan Express  96.31       10164    Resolved
# 13            1980’s GM Manhattan Express  96.31       10425  In Process
# 14  1969 Harley Davidson Ultimate Chopper  95.70       10417    Disputed
# 15    1932 Alfa Romeo 8C2300 Spider Sport  92.03       10367    Resolved
# 16    1932 Alfa Romeo 8C2300 Spider Sport  92.03       10407     On Hold
# 17    1932 Alfa Romeo 8C2300 Spider Sport  92.03       10420  In Process
# 18            American Airlines: B767-300  91.34       10179   Cancelled
# 19            American Airlines: B767-300  91.34       10262   Cancelled

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
cur.execute('''SELECT e.lastName || ', ' || e.firstName as fullname, p.productName
                 FROM employees e
                 JOIN customers c
                   ON e.employeeNumber = c.salesRepEmployeeNumber
                 JOIN orders o
                   ON o.customerNumber = c.customerNumber
                 JOIN orderDetails od 
                   ON o.orderNumber = od.orderNumber
                 JOIN products p
                   ON od.productCode = p.productCode
             
             ORDER BY 1
                      ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print(len(df))
df.head(20)
# Out:
# 2996
#         fullname                                  productName
# 0   Bondur, Loui                     1952 Alpine Renault 1300
# 1   Bondur, Loui                       1962 LanciaA Delta 16V
# 2   Bondur, Loui                               1958 Setra Bus
# 3   Bondur, Loui                       1940 Ford Pickup Truck
# 4   Bondur, Loui                        1926 Ford Fire Engine
# 5   Bondur, Loui                             1940s Ford truck
# 6   Bondur, Loui                      1939 Cadillac Limousine
# 7   Bondur, Loui                     1962 Volkswagen Microbus
# 8   Bondur, Loui                  1980’s GM Manhattan Express
# 9   Bondur, Loui  1996 Peterbilt 379 Stake Bed with Outrigger
# 10  Bondur, Loui                              1982 Camaro Z28
# 11  Bondur, Loui                            2001 Ferrari Enzo
# 12  Bondur, Loui                           1969 Corvair Monza
# 13  Bondur, Loui                             1969 Ford Falcon
# 14  Bondur, Loui                            1903 Ford Model A
# 15  Bondur, Loui                     Collectable Wooden Train
# 16  Bondur, Loui                          1904 Buick Runabout
# 17  Bondur, Loui                        18th century schooner
# 18  Bondur, Loui             1912 Ford Model T Delivery Wagon
# 19  Bondur, Loui               1962 City of Detroit Streetcar

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
cur.execute('''SELECT COUNT(p.productName) AS numberOfProductSold, e.lastName || ', ' || e.firstName as fullname 
                 FROM employees e
                 JOIN customers c
                   ON e.employeeNumber = c.salesRepEmployeeNumber
                 JOIN orders o
                   ON o.customerNumber = c.customerNumber
                 JOIN orderDetails od 
                   ON o.orderNumber = od.orderNumber
                 JOIN products p
                   ON od.productCode = p.productCode
             GROUP BY 2
             ORDER BY 1 DESC
                      ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head(20)
# Out:
#     numberOfProductSold           fullname
# 0                   396  Hernandez, Gerard
# 1                   331   Jennings, Leslie
# 2                   272   Castillo, Pamela
# 3                   236        Bott, Larry
# 4                   220       Jones, Barry
# 5                   211     Vanauf, George
# 6                   185       Fixter, Andy
# 7                   185       Marsh, Peter
# 8                   177       Bondur, Loui
# 9                   152   Patterson, Steve
# 10                  142    Tseng, Foon Yue
# 11                  137        Nishi, Mami
# 12                  124    Firrelli, Julie
# 13                  114     Gerard, Martin
# 14                  114   Thompson, Leslie

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
